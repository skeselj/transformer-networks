# %% [markdown]
# # Inspect

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of utils.cv_sampler failed: Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "../utils/cv_sampler.py", line 10
#     def __init__(self, is_test=False, source, mip=1, dim=512):
# SyntaxError: non-default argument follows default argument
# ]

# %%
import sys, h5py, math
import numpy as np
import scipy, scipy.ndimage as img
import matplotlib.pyplot as plt
plt.set_cmap("Greys_r")

sys.path.append("..")
from utils.cv_sampler import Sampler
from utils.helpers import rem_margin

# %%
is_test = False   # args.test
mip = 2
final_dim = 256  # dimension of pairs we save                                               
margin = 0.125   # on each side   

from utils.cv_sampler import Sampler
big_dim = int(math.ceil(final_dim / (1 - 2*margin)))
sampler = Sampler(source='pinky40_unaligned', \
                  mip=mip, dim=big_dim, is_test=is_test)
#chunk = sampler.get_chunk()
m = 256
(x,y,z) = (20505-m*2**2, 31061-m*2**2, 551); d = 2*m*2**2
chunk = sampler.chunk_at_global_coords((x,y,z),(x+d,y+d,z+1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-4543a3fab465> in <module>()
#       6 from utils.cv_sampler import Sampler
#       7 big_dim = int(math.ceil(final_dim / (1 - 2*margin)))
# ----> 8 sampler = Sampler(source='pinky40_unaligned',                   mip=mip, dim=big_dim, is_test=is_test)
#       9 #chunk = sampler.get_chunk()
#      10 m = 256
#
# /usr/people/skeselj/seungmount/research/skeselj/transformer/spynet/utils/cv_sampler.pyc in __init__(self, is_test, source, mip, dim)
#       8     self.basil = 'gs://neuroglancer/basil_v0/raw_image'
#       9     self.pinky40_unaligned = 'gs://neuroglancer/pinky40_v11/image'
# ---> 10     def __init__(self, is_test=False, source, mip=1, dim=512):
#      11         httplib2shim.patch()
#      12         if source == 'basil': self.source = self.basil
#
# /usr/local/lib/python2.7/dist-packages/cloudvolume/cloudvolume.pyc in __init__(self, cloudpath, mip, bounded, fill_missing, cache, progress, info, provenance)
#      98       cache=False, progress=INTERACTIVE, info=None, provenance=None):
#      99
# --> 100     self.path = lib.extract_path(cloudpath)
#     101
#     102     self.progress = progress
#
# /usr/local/lib/python2.7/dist-packages/cloudvolume/lib.pyc in extract_path(cloudpath)
#      38
#      39   match = re.match(protocol_re, cloudpath)
# ---> 40   (protocol,) = match.groups()
#      41   cloudpath = re.sub(protocol_re, '', cloudpath)
#      42
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %%
plt.figure(figsize=(30,30))
plt.imshow(chunk.T)
plt.show()
